# %% [markdown]
# ---
#
# # Microeconometrics Replication Project
# Felipe Augusto Azuero Mutis
# University of Bonn
#
# ---

# %%
# Load libraries.

packages <- c(
    "IRdisplay",
    "yaml",
    "AER",
    "cowplot",
    "dplyr",
    "ggplot2",
    "ggstance",
    "grf",
    "gt",
    "haven",
    "purrr"
)
 
suppressWarnings(suppressMessages( invisible(
    lapply(
        packages,
        library,
        character.only = TRUE,
        warn.conflicts = FALSE,
        quietly = TRUE
    )
)))

# %%
# Set options.

options(repr.plot.width=7, repr.plot.height=7, repr.plot.res=200, warn=-1)

# %%
# Load helper code files.

suppressWarnings(source("./code/descriptiveStatistics/tablesAndFigures.R"))
suppressWarnings(source("./code/analysisHelper.R"))
suppressWarnings(source("./code/forestHelper.R"))

# %% [markdown]
# # Replication of Allcott, H., Braghieri, L., Eichmeyer, S., & Gentzkow, M. (2020). The welfare effects of social media.
#
# ---

# %% [markdown]
# In this document you can find my attempt to replicate the main results obtained by Allcott, H., Braghieri, L., Eichmeyer, S., & Gentzkow, M. in the article *\"The welfare effects of social media\"*, as the final project for the Microeconometrics course taught at the University of Bonn in the Summer Semester of 2020.  In addition, you can find a few independent extensions to the research paper.
#
# The figures and tables in this notebook are, for the most part, a reproduction of those found in the original article unless otherwise specified.  The labels and numbering also follow the same pattern as the one in the original article.  Likewise, the footnotes in the graphs are the same used by the authors in their article. In the case of any additional notes, different from the ones in the original article, it will be made clear that they are independent additions.
#
# For ease of comparison, I attempted to make the graphics reproduced as visually similar as possible to those presented in Allcot et al (2020).  Keeping its original structure and a similar color palette.  However, due to the difference in the software with which they were generated and in the publication format, some aesthetic differences exist.

# %% [markdown]
# ## Introduction

# %% [markdown]
# In recent years, social networks have become one of the most ubiquitous tools in the daily lives of a large part of the world's population.  Its use, not only as an instrument of social interaction, but also as a medium of information has managed to reshape the way we interact with reality.  According to the GlobalWebIndex (2020a), users spend an average of 144 minutes per day on various social networks and messaging apps.  The impact of the widespread adoption of these relatively new technologies on our lives is to this day still difficult to quantify.
#
# Using a large-scale randomized experiment, Allcott et al. (2020) attempt to determine the welfare impact of Facebook.  Facebook is one of the largest social networks in the world, with a total of 2.60 billion active users per month (Facebook, 2020).  In 2016, Facebook reported that the average user spent 50 minutes per day on the platform and its sister platforms Instagram and WhatsApp (Facebook, 2016).
#
# To answer their research question, the authors recruited 2,743 Facebook users residing in the United States through advertising on the platform prior to the November 2018 midterm elections.  The authors then randomly divided those with a willingness-to-accept (WTA) to deactivate Facebook for 4 weeks after the election of less than \$102 into two groups, the control group and the treatment group.  Those in the treatment group were paid to deactivate Facebook for 4 weeks.  The authors then used the treatment effect of deactivation to assess how Facebook affects various individual and social welfare variables.
#
# The authors divided their main findings on the effect of Facebook into four major groups:
#
# - Substitution patterns.
# - Political externalities, proxied by news knowledge, political engagement, and political polarization.
# - Subjective well-being.
# - Whether deactivation affected people’s demand for Facebook after the study was over, as well as their opinions about Facebook’s role in society.
#
# The different variables used in each set are explained in more detail in the sections below.
#
# Furthermore, Allcot et al (2020) attempt to answer how to measure the economic benefits of a platform such as Facebook, and whether users evaluate these benefits differently after deactivation.
#
# As of the date of its publication, this article is the largest published experiment measuring how Facebook affects social and individual welfare.  According to the authors the magnitude of the experiment allows for sufficient explanatory power to determine the different effects under study.
#
# Studies such as this one help us to begin to elucidate the consequences of the massive adoption of new instruments of social interaction.  In a context such as the present one, with a public health crisis unprecedented in contemporary history, both in its magnitude and in the way it interrupted the normal development of our daily lives, it is important to understand how new technologies can impact our social and individual well-being. Due to the different lockdowns in various countries around the world people are looking for alternatives to socialize and entertain themselves, 43\% of respondents in various countries reported spending more time on social networks due to the COVID-19 outbreak (GlobalWebIndex, 2020b).  It is important to understand how this increased use of social networks can enhance or mitagate the effects of a crisis, such as the one we are going through, on people's well-being.

# %% [markdown]
# ## Main Findings by the Authors

# %% [markdown]
# The following is a short summary of the main results presented by the authors.
#
# ### On how Facebook affects individual and social welfare measures:
#
# #### Substitution patterns:
# - On average, people in the treatment group had an extra 60 free minutes per day.
# - Surprisingly, participants in the treatment group spent less time using other social networks different from Facebook, as well as less time on online activities in general.
# - Those who deactivated Facebook spent more time on offline activities, such as watching TV alone, or with family and friends.
# - Participants in the treatment group spent less time consuming news sources, both online and offline.
#
# #### Political externalities:
# - Deactivating Facebook was linked to a reduction in news awareness and attention to politics.
# - Although disabling Facebook significantly reduced polarization on policy issues, no significant reduction in affective polarization or polarization in factual beliefs was found.
# - There was no significant difference in political engagement between the control and treatment groups.
# - In general the overall polarization index fell by 0.16 standard deviations.
#
# #### Subjective well-being:
# - The overall subjective well-being of those in the treatment group improved significantly compared to those in the control group.
# - In general the overall index of subjective well-being rose by 0.09 standard deviations
#
# #### Facebook demand after the study was over and role in society:
# - Reported use of the Facebook App a few weeks after the end of the study in the participants who belonged to the treatment group is on average 11 minutes less than in the control group.
# - Five percent of the participants in the treatment group still had Facebook deactivated nine weeks after the study concluded.
# - This may indicate that deactivation could lead to an appreciation of the overall subjective well-being benefits of not having Facebook.
# - Deactivation also led participants in the treatment group to have a different assessments of both the negative and positive qualities of the social network.
#
#
# ### The Consumer Surplus from Facebook:
# To measure the consumer surplus from Facebook, the authors used the WTA of the participants to deactivate Facebook for 4 weeks. In the first inquiry, the average WTA of the participants to deactivate for weeks 1 to 4 was of \$180.  If we multiply this average by the number of active users in the United States it would imply that the consumer surplus from Facebook would be of approximately 3.87 billion dollars per day in the US alone.  After the experiment was conducted, the authors again inquired about the willingness-to-accept to deactivate Facebook for weeks 5 to 8 among the participants.  The authors found that previous deactivation caused the WTA to fall on average by 14\%.  This could indicate that calculating the consumer surplus of Facebook by traditional means could overestimate its true value, and that people do not correctly evaluate the benefits they get from using the network.  Nevertheless, the Facebook consumer surplus remains extremely high.

# %% [markdown]
# ## Experimental Design
# #### *(Section I in the original paper)*

# %% [markdown]
# ### *A. Experiment Overview*

# %% [markdown]
# I will now present a brief summary of the experimental design proposed by the authors, highlighting its most important points, as I consider important to outline the way in which the experiment was carried out for a better understanding of the rest of the article.  **Figure 1**, reproduced from the original article, shows a visual summary of the experimental design and the timeline.
#
# ![Figure 1. Experimental Design](./figures/figureOne.svg)
#
# The experiment, according to Alcott et al. (2020), can be divided into eight parts:
#
#
# 1. **Recruitment**:
#     - Recruitment took place from September 24 and October 3.
#     - The recruitment process was carried out through Facebook ads targeting certain demographic cells.  This was done in order to obtain a representative sample of Facebook users.
# 2. **Pre-screen**:
#     - After clicking on the ad the users were presented, in addition to a short survey where they had to answer certain demographic questions, the consent form.
#     - Only users residing in the United States, born between 1900 and 2000, and who also reported using Facebook for more than 15 minutes and no more than 600 minutes a day, were accepted in the next stage.
# 3. **Baseline survey**:
#     - Those who decided to participate in the study were presented with a new survey in which they were asked to answer a variety of questions.  These answers were used to calculate, what will be called from now on, the baseline values.
#     - They were also informed that they would be asked to deactivate Facebook for two 24-hour periods.
# 4. **Midline survey**:
#     - On October 11, an email was sent to those who agreed to the deactivation and whose responses in the baseline survey met a certain quality criteria, inviting them to the midline survey.
#     - In the survey, users were asked to deactivate Facebook for a period of 24 hours and were guided through the process.
#     - Then, using a Becker-DeGroot-Marschak (BDM) mechanism, the participants' WTA to deactivate Facebook for a period of 4 weeks was determined.
#     - Those with a strictly lower WTA than the price displayed were informed that they should deactivate Facebook for 4 weeks instead of 24 hours.
#     - A second BDM mechanism was used to determine the WTA to remain deactivated for 4 weeks instead of 24 hours after the endline.
# 5. **Endline survey**
#     - On November 8, an email was sent inviting participants to the endline survey.
#     - In the endline survey the same variables as in the baseline survey were measured. With the exception of some questions that were updated due to the change in circumstances, the questions were identical to those in the baseline survey.
#     - Similar to the midline survey, participants were asked to deactivate Facebook for a period of 24 hours.
#     - Once again, the WTA to remain deactivated for the next four weeks was elucidated.
# 6. **Post-endline survey**
#     - On December 3, an email was sent inviting participants to the post-endline survey.
#     - In it, users were asked the number of minutes per day they were active on Facebook for the last seven days.
# 7. **Post-endline emails**
#     - An email was sent to participants on November 20 with links to information on how to reduce the use of social media on smartphones.
#     - A second email was sent on November 25 to the participants with links related to political causes.
# 8. **Daily text messages**
#     - During the 6 weeks between the baseline and the endline, daily text messages were sent with questions about various aspects of subjective well-being in order to have real-time measurements.

# %% [markdown]
# ### *B. Randomization*
#
# The authors describe the BDM mechanism used to assign participants to the different groups as follows:
#
# > *The survey explained, “The computer has randomly generated an amount of money to offer you to deactivate your Facebook account for the next 4 weeks. Before we tell you what the offer is, we will ask you the smallest offer you would be willing to accept. If the offer the computer generated is above the amount you give, we will ask you to deactivate for 4 weeks and pay you the offered amount if you do. If the offer is below that amount, we will not ask you to deactivate.” We then asked several comprehension questions to make sure that participants understood the mechanism. We did not tell participants the distribution or support of the offer prices, both because we did not want to artificially truncate the distribution of elicited WTA and because prior studies have found that providing information on the bounds of the offer price distribution can affect BDM valuations.*  (Alcott et al., 2020)
#
# For the deactivation in weeks 1-4, 33\% of participants were offered a deactivation price of $p = \$102$; 67\%, $p = \$0$ and 0.2\% $p \in \left [0 , 170 \right ]$ from a uniform distribution.  The authors balanced the groups offered $p = \$102$ and $p = \$0$ within 48 strata. Those in the two groups mentioned previously, with a WTA of less than \\$102, were part of the impact evaluation sample.  In the impact evaluation sample those offered a $p = \$0$, were selected for the control group, and the others offered $p = \$102$, the treatment group.
#
# For the deactivation in weeks 5-8, 99.2\% of participants were offered a deactivation price of $p' = \$0$ and 0.2\% were offered $p' \in \left [0 , 170 \right ]$ from a uniform distribution.

# %% [markdown]
# ### *C. Outcome Variables*
#
# The authors divided the variables of interest into nine families.  The following table, of my authorship, summarize the variables of interest according to their different families.
#
# | Family                  | Variable name                                 |
# |-------------------------|-----------------------------------------------|
# | Substitute time uses    | Facebook minutes                              |
# |                         | Non-FB social media time                      |
# |                         | Non-social online time                        |
# |                         | TV alone time                                 |
# |                         | Non-screen alone time                         |
# |                         | Friends and family time                       |
# | Social interaction      | Friends met in person                         |
# |                         | Offline activities                            |
# |                         | Diverse interactions                          |
# | Substitute news sources | Facebook news                                 |
# |                         | Print news                                    |
# |                         | Radio news                                    |
# |                         | Local TV news                                 |
# |                         | Network TV news                               |
# |                         | Cable TV news                                 |
# |                         | Non-FB social media news                      |
# |                         | Non-social online news                        |
# |                         | Number of tweets                              |
# | News knowledge          | Follow politics                               |
# |                         | Follow Trump                                  |
# |                         | News minutes                                  |
# |                         | News knowledge                                |
# |                         | Fake news knowledge                           |
# | Political engagement    | Voted                                         |
# |                         | Clicked politics email                        |
# | Political polarization  | Party affective polarization                  |
# |                         | Trump affective polarization                  |
# |                         | Party anger                                   |
# |                         | Congenial news exposure                       |
# |                         | Issue polarization                            |
# |                         | Belief polarization                           |
# |                         | Vote polarization                             |
# | Subjective well-being   | Happiness                                     |
# |                         | Life satisfaction                             |
# |                         | Loneliness × (-1)                             |
# |                         | Depressed × (-1)                              |
# |                         | Anxious × (-1)                                |
# |                         | Absorbed                                      |
# |                         | SMS happiness                                 |
# |                         | SMS positive emotion                          |
# |                         | SMS not lonely                                |
# | Post-experiment use     | Planned post-study use change                 |
# |                         | Clicked time limit email × (-1)               |
# |                         | Speed of reactivation Facebook mobile app use |
# | Facebook opinions       | Improves social life                          |
# |                         | Good for you                                  |
# |                         | Good for society                              |
# |                         | Makes people happy                            |
# |                         | People would miss Facebook                    |
# |                         | Helps follow news                             |
# |                         | Clickbait, fake news × (-1)                   |
# |                         | Less polarized                                |
# |                         | Positive impacts                              |
# |                         | Negative impacts × (-1)                       |

# %% [markdown]
# ## The Data
# #### *(Not in the original paper)*

# %%
# Download the replication files archive if it doesn't exists already.

if(!file.exists("./data/replicationArchive/replicationArchive.zip")) {
    
    ## Download the files
    fileUrl <- paste("https://www.openicpsr.org/openicpsr/project/112081/", 
                     "version/V1/download/project?dirPath=/openicpsr/112081", 
                     "/fcr:versions/V1", sep = "")
    destFile <- "./data/replicationArchive/replicationArchive.zip"
    download.file(fileUrl, destFile, method = "curl")
    
    ## Creates a .txt file with the date and time that the files were 
    ## downloaded
    sink("./data/replicationArchive/timeOfDownload.txt")
    cat(format(Sys.time(), "%Y-%m-%d %X %Z"))
    cat("\n")
    sink()
    
}

# Give the last date and time of download.
print(paste("The replication archive was last downloaded on: ", 
            readLines("./data/replicationArchive/timeOfDownload.txt")))
# Out:
# [1] "The replication archive was last downloaded on:  2020-05-29 17:27:45 CEST"

# %%
## Unzips the replication archive file.

unzip("./data/replicationArchive/replicationArchive.zip", 
      exdir = "./out/replicationFiles")

# %% [markdown]
# The authors provided a replication archive with the data and the code used to generate the article, which can be found in [the self-publishing repository openICPSR](https://www.openicpsr.org/openicpsr/project/112081/version/V1/view).  In addition to this, the archive has detailed instructions on how to run the code and generate as a final result the submitted article.  Because the raw data contains personally identifiable information, it is not publicly available. However, the data generated after a clean-up process that removes all personally identifiable information is available in the replication archive. Furthermore, and for reasons of transparency, the code used in this process is also made available by the authors.  Consequently, the public replication archive contains a number of anonymized datasets.
#
# Following the instructions and using the supplied code I was able to merge the various databases and generate a large final dataset.  In order to upload the file and due to storage restrictions, I compressed the final database using [`bzip2`](http://www.bzip.org/).

# %%
# Load the data
finalData <- read_stata(bzfile("./data/final_data.dta.bz2"))

# Load the configuration file
suppressWarnings(configFile <- 
                   yaml.load_file("./out/replicationFiles/config.yaml"))

# %% [markdown]
# Although the code to generate the different tables and figures of the article, as well as those in the online appendix, is available in the replication archive, the code used to generate the tables and figures in this notebook is written by me, based on the code provided by the authors.  For this purpose, I used the open-source software `R`, whereas the supplied code is mostly in `Stata`.

# %% [markdown]
# ## Descriptive Statistics
# #### *(Section II in the original paper)*
#
# **Table 1**, reproduced from the original article, shows the different sample sizes throughout the course of the experiment described in Section I.

# %% [markdown]
# <p style="text-align: center;"> <b>Table 1—Sample Sizes</b> </p>
#
# | Phase                    | Sample Size                                                        |
# |--------------------------|--------------------------------------------------------------------|
# | Recruitment and baseline | *N* = 1,892,191 were shown ads                                     |
# |                          | *N* = 32,201 clicked on ads                                        |
# |                          | *N* = 22,324 completed pre-screen survey                           |
# |                          | *N* = 20,959 from the United States and born between 1900 and 2000 |
# |                          | *N* = 17,335 had 15 < daily Facebook minutes $\leq$ 600            |
# |                          | *N* = 3,910 finished baseline                                      |
# |                          | *N* = 2,897 had valid baseline and where randomized of which:      |
# | Midline                  | *N* = 2,897 began midline                                          |
# |                          | *N* = 2,743 received a price offer, of which:                      |
# |                          | &nbsp;&nbsp;&nbsp;&nbsp;*N* = 1,661 were in impact evaluation sample                       |
# | Endline                  | *N* = 2,710 began endline                                          |
# |                          | *N* = 2,684 finished endline of which:                             |
# |                          | &nbsp;&nbsp;&nbsp;&nbsp;*N* = 1,637 were in impact evaluation sample                       |
# | Post-endline             | *N* = 2,067 reported Facebook mobile app use, of which:            |
# |                          |&nbsp;&nbsp;&nbsp;&nbsp; *N* = 1,219 were in impact evaluation sample                       |

# %% [markdown]
# **Table 2** shows a comparison of the average demographic characteristics of the impact evaluation sample with those of adult Facebook users and those of the U.S. adult population, as calculated by Alcott et al. (2020).

# %%
tableTwo <- genTableTwo(finalData)
display_html(tableTwo)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# Compared with the population characteristics, it can be observed that the impact evaluation sample used in the study is relatively young, Democratic, well educated, and uses Facebook heavily.
#
# **Table 3** documents the compliance rates of both the control and treatment groups at the various stages of the experiment.

# %%
tableThree <- genTableThree(finalData, configFile)
display_html(tableThree)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# As can be seen in the table, a statistically significant greater proportion of those in the treatment group responded to the post-endline survey.  The authors do not consider this to be very problematic, since the only variable gathered at this stage, and used in the impact analysis, is Facebook mobile app use.  And they argue that the conclusions reached are not affected using Lee (2009) bounds to account for attrition.

# %% [markdown]
# ## Identification
# #### *(Not in the original paper)*
#
# ### Impact evaluation sample
#
# In this part of the identification I will focus on the impact evaluation sample, consisting of those participants who were invited to the midline survey and had a willingness to accept of less than \$102.
#
# The purpose of the study is to determine the effect of deactivation on various variables of interest.  Let's call $Y$ the outcome variable at endline and $D$ the percentage of checks where the person was observed to be deactivated.  The following causal graph shows the relationship between these variables.
#
# <br><center><img src="./figures/identificationOne.svg" alt="Casual Graph 1" style="width:200px;height:100px;"></center>
#
#
#
# As can be seen in the graph, $D$ and $Y$ are connected by a causal effect and a number of unspecified *back-door-paths* that cannot be blocked.  Trying to measure the effect with a simple linear regression could give biased estimates.
#
# Since a controlled experiment was performed, Alcott et al. (2020) were able to randomly divide the participants using the mechanism explained above into two groups, called treatment and control.  Participants in the treatment group were paid \\$102 to stay deactivated from Facebook for 4 weeks, while those in the control group were not offered any money.  Calling the treatment group indicator, $T$, we can see the relationship between these variables in the following causal graph.
#
# <br><center><img src="./figures/identificationTwo.svg" alt="Casual Graph 2" style="width:300px;height:150px;"></center>
#
#
#
# As we can see, the variable $T$ can be used as a valid instrument of $D$ to calculate the effect of deactivation since it only affects $Y$ through $D$.
#
# Let's call $Y_{b}$ the outcome variable at baseline, and $I_{b}$ the index containing $Y$ also at baseline.  If these elements are present for $Y$, we can further isolate their effect on $Y$ as presented in the following causal graph.  Let $W$ be a set of observable and unobservable variables.
#
# <br><center><img src="./figures/identificationThree.svg" alt="Casual Graph 3" style="width:500;height:200;"></center>
#
#
# There are still backdoor paths from $D$ to $Y$ that cannot be blocked.  $T$ is still a valid instrument and can be used to estimate the LATE of deactivating Facebook.
#
# ### Limitations
#
# Although one of the advantages of experiments such as this is the possibility of designing a mechanism to achieve randomization within strata between the control and treatment groups, there are also limitations as noted by the authors.  First the willingness to participate in the experiment by both observable and unobservable variables.  This limitation can be appreciated in **Table 2**, where it can be seen that the sample varies in certain characteristics from the population. Another limitation is that many variables are self-reported, which can create problems in the estimations.
#
#
# <br><center><img src="./figures/identificationFour.svg" alt="Casual Graph 4" style="width:300px;height:200px;"></center>
#
#
# An example of this limitation is the experimenter's demand effect.  If we assume that unobservable $E$ captures this effect, we can appreciate in the graph above that $T$ is no longer a valid instrument for $D$.  Alcott et al. (2020) address this issue in **Section IVF** of the original article, and argue that there appears to be no evidence that this effect exists.

# %% [markdown]
# ## Empirical Strategy
# #### *(Section III in the original paper)*

# %% [markdown]
# The authors estimated the local average treatment effects (LATE) of deactivating Facebook using the following regression:
#
# $$Y_{i} = \tau D_{i} + \rho \mathbf{Y}_{i}^{b} + v_{s} + \varepsilon_{i}$$
#
# Where:
# - $Y_{i}$ is an outcome variable measured at endline.
# - $\mathbf{Y}_{i}^{b}$ is a vector including the baseline value of the outcome and the baseline value of the index that includes the outcome. $\mathbf{Y}_{i}^{b}$ excludes:
#     - The baseline value of the outcome for outcomes that do not have a baseline value or when $Y_{i}$ is an index.
#     - The baseline index when $Y_{i}$ is not included in an index.
# - $D_{i}$ is the percentage of deactivation checks where person $i$ was observed to be deactivated.
# - $v_{s}$ is the vector containing the 48 stratum dummies.
#
# Define $T_{i} \in \left \{ 1, 0 \right \}$ as the treatment group indicator.  Using $T_{i}$ as an instrument for $D_{i}$, $\tau$ measures the LATE of deactivation.
#
# To calculate the effects of deactivation I used the two-stage least squares (2SLS) method with robust standard errors.  Some coefficients reported here are slightly different to those reported in the original article.

# %% [markdown]
# ## Impact Evaluation
# #### *(Section IV in the original paper)*

# %% [markdown]
# In this part of the paper the authors present the treatment effect of deactivating Facebook on various variables and their indexes divided into four groups of results.
#
# The figures presented in the original article and reproduced here show the LATEs and 95\% confidence intervals evaluated using the equation described in the "Empirical Strategy" section normalizing $Y_{i}$ so that the control group standard deviation is equal to 1.
#
# As a complement I will also present tables, not included in the original article, for each outcome group displaying the treatment effect, the standard error and the *p*-value for each estimate, using the same specifications used to build the figures..
#
# In addition, in this section the authors present heterogeneous treatment effects, and evidence on experimenter demand effects.

# %%
## Set options

## Specify analytic sample
sample <- "main"
weights <- "unweighted"

# Define variable sets
source("./code/DefineVarsets.R")

## Add index to variable sets
for (vset in vset_list) {
    if (vset == "secondary") {
        assign(paste("vs_", vset, sep = ""),
               eval(parse(text = paste(
                   "varset_", vset, sep = ""
               ))))
    } else{
        assign(paste("vs_", vset, sep = ""), c(eval(parse(
            text = paste("varset_", vset, sep = "")
        )),
        paste("index_", vset, sep = "")))
    }
}

## Run normalized regressions.
df <- importData(finalData, sample, weights)

## Rename normalized variables to run regressions.
for(vset in vset_list) {
    for (yvar in eval(parse(text = paste("varset_", vset, sep = "")))) {
        for (time in c("", "_b")) {
            names(df)[names(df) == paste(yvar, time, sep = "")] <-
                paste(yvar, time, "_nn", sep = "")
            names(df)[names(df) == paste(yvar, time, "_nm", sep = "")] <-
                paste(yvar, time, sep = "")
        }
    }
}

## Run regressions.
for(vset in vset_list) {
    for (yvar in eval(parse(text = paste("vs_", vset, sep = "")))) {
        eq <- setEquation(vset, yvar)
        nam <- paste(yvar, "_IV", sep = "")
        assign(nam, ivreg(eq, data = df, weights = weight_main))
        assign(paste(nam, "_coeftest", sep = ""),
               coeftest(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
        assign(paste(nam, "_coefci", sep = ""),
               coefci(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
    }
}

# %% [markdown]
# ### *A. Substitutes for Facebook*
#
# **Figure 2** and the table that follows it show the treatment effects on substitutes for Facebook.

# %%
figTwoDF <- genFigDF(c("sub_news", "social", "sub_time"))
figureTwo <-
    genMainFigure(figTwoDF) + labs(title = "Figure 2. Substitutes for Facebook")
figureTwo
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents local average treatment effects of Facebook deactivation estimated using equation (1). All variables are normalized so that the Control group endline distribution has a standard deviation of 1. Error bars reflect 95 percent confidence intervals. See Section IC for variable definitions.<i>Facebook minutes</i> is not included in the substitute time uses index, and <i>Facebook news</i> is not included in the substitute news sources index, so we visually separate these two variables from the other variables in their respective families. We also visually separate online and offline time uses and news sources, although all online and offline substitutes enter their respective indexes.<br><br><b><i>Note (extension)</i>: The separations mentioned in the original footnote cannot be seen in the reproduced figure.</b></p>

# %%
extraTableTwo <- genExtraTable(figTwoDF, "Substitutes for Facebook")
display_html(extraTableTwo)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# To measure the effect of all variables except *Facebook minutes*, participants in both surveys were asked how much time they had spent on the activity in the past four weeks relative to what is usual for them.  Respondents were asked to answer using a five-point scale ranging from "A lot less" to "A lot more".  *Facebook minutes* was reported in number of minutes.
#
# Summarizing the statistically significant effects:
# - In general, all components of the *Substitute time uses index*, as well as the index itself, show a treatment effect statistically significant. It is relevant to note that the *Substitute time uses index* does not include *Facebook minutes*.
# - Facebook seems to be a complement to online activities as well as a supplement to offline activities.
# - The only social interaction effect to be statistically significant is *Offline activities*.  The authors note that among the specific activities the ones with the highest point estimates are: going out to dinner, getting together with friends, and spending time with parents. The rest show no evidence of experiencing any change.
# - Both *Facebook news* and *Non-FB social media news* show a significant and negative effect.

# %% [markdown]
# ### *B. Effects on News and Political Outcomes*
#
# **Figure 3** and the table that follows it show the treatment effects on news and political outcomes

# %%
figThreeDF <- genFigDF(c("voting", "polarize", "news"))
figureThree <-
    genMainFigure(figThreeDF) + labs(title = "Figure 3. Effects on News and Political Outcomes")
figureThree
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>:This figure presents local average treatment effects of Facebook deactivation estimated using equation (1). All variables are normalized so that the Control group endline distribution has a standard deviation of 1. Error bars reflect 95 percent confidence intervals. See Section IC for variable definitions.</p>

# %%
extraTableThree <-
    genExtraTable(figThreeDF, "Effects on News and Political Outcomes")
display_html(extraTableThree)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# To measure news knowledge the authors used quiz questions and measured the number of accurate responses.
#
# All components, except the *Fake news knowledge* one, of the *News knowledge index* seem to suffer a significant effect with deactivation. Compared to the control group, those in the treatment group appear to be less informed about current news after the experiment was completed.  Furthermore, as can be seen in the graphs, political engagement seems to remain unaffected by deactivation.
#
# The effect on political polarization is statistically significant.  Of the components of this index, the effects on *Congenial news exposure* and *Issue polarization* are statistically significant. *Congenial news exposure* measures the number of times that people reported seeing news that made them better understand their party's point of view relative to the opposing party's point of view.  The effect on this variable is not only strongly significant but also quite (negatively) large, and is one of the major causes of the large negative effect reported on the *Political polarization index*.
#
# **Figure 4** shows how the treatment affects *Issue polarization*.

# %%
figureFour <- genFigFour(finalData)
figureFour
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents kernel density plots of issue opinions for Democrats and Republicans in Treatment and Control at endline. Issue opinions are attitudes about nine current political issues on a scale from −5 to +5, such as “To what extent do you think that free trade agreements between the US and other countries have been a good thing or a bad thing for the United States.” See online Appendix B for a list of all nine issue questions. To construct the <i>issue opinions measure</i>, for each issue question $q$, we normalize responses by the standard deviation in the Control group, determine Democrats’ and Republicans’ average responses $\mu_{q}^{D}$ and $\mu_{q}^{R}$, recenter so that $\mu_{q}^{D} + \mu_{q}^{R} = 0$, and resign so that $\mu^{R} > 0$. Define $\tilde{y}_{iq}$ as individual $i$’s normalized, recentered, and re-signed response to question $q$. Thus $\tilde{y}_{iq}$  reflects the strength of individual $i$’s agreement with the average Republican. Define $\sigma_{q}$ as the Control group within-person standard deviation of $\tilde{y}_{iq}$ for question $q$. This measures how much people’s views change between baseline and endline, and allows us to place higher weight on issues about which views are malleable over the deactivation period. The preliminary <i>issue opinion</i> measure is $Y_{i} = \sum_{q} \tilde{y}_{iq} \sigma_{q}$, and the final <i>issue opinion</i> measure plotted in the figure is $Y_{i}$ divided by the Control group standard deviation</p>

# %% [markdown]
# As can be seen in the figure, the deactivation resulted in both Republicans and Democrats moving more to the center on polarizing issues.  To measure how large this change is, Alcott et al. (2020) compare the result they obtained, a reduction of 0.15 standard deviations in the index of political polarization due to the deactivation, with that of Boxell (2020).  Boxell (2020) estimates that the polarization index increased by 0.38 standard deviations between 1996 and 2006.

# %% [markdown]
# ### *C. Effects on Subjective Well-Being*
#
# **Figure 5** and the table that follows it show the treatment effects on subjective well-being.

# %%
figFiveDF <- genFigDF(c("swb"))
figureFive <-
    genMainFigure(figFiveDF) + labs(title = "Figure 5. Effects on Subjective Well-Being")
figureFive
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>:This figure presents local average treatment effects of Facebook deactivation estimated using equation (1). All variables are normalized so that the Control group endline distribution has a standard deviation of 1. Error bars reflect 95 percent confidence intervals. See Section IC for variable definitions.</p>

# %%
extraTableFive <-
    genExtraTable(figFiveDF, "Effects on Subjective Well-Being")
display_html(extraTableFive)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# In general, subjective well-being has a positive and significant effect with deactivation.   Being the largest significant effect on the variable *Life satisfaction*.
#
# The authors compare the positive effect of an increase of 0.09 standard deviations on subjective well-being with various benchmarks. The comparison I found most interesting and which I will share below, reads as follows:
#
# > ...*[A] \\$10,000 increase in income is conditionally associated with a 0.027 standard deviation increase in SWB. Thus, the effect of deactivating Facebook is equal to the conditional difference in subjective well-being from about \\$30,000 additional income.* (Alcott et al., 2020)

# %% [markdown]
# ### *D. Post-Experiment Facebook Use and Opinions*
#
# **Figure 6** and the table that follows it show the treatment effects on post-experiment Facebook use and opinions about Facebook.

# %%
figSixDF <- genFigDF(c("fbopinions" ,"postexp"))
figureSix <-
    genMainFigure(figSixDF) + labs(title = "Figure 6. Effects on Post-Experiment Facebook Use and Opinions")
figureSix
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>:This figure presents local average treatment effects of Facebook deactivation estimated using equation (1). All variables are normalized so that the Control group endline distribution has a standard deviation of 1. Error bars reflect 95 percent confidence intervals. See Section IC for variable definitions.</p>

# %%
extraTableSix <-
    genExtraTable(figSixDF, "Effects on Post-Experiment Facebook Use and Opinions")
display_html(extraTableSix)
# Out:
# <table style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif; display: table; border-collapse: collapse; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; background-color: #FFFFFF; width: 75%; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3;">
#   <thead style="">
#     <tr>
# ...

# %% [markdown]
# As discussed above, this set of variables is related to reported changes in participants' subjective well-being due to deactivation.   If the respondents noticed an improvement in their subjective well-being with the deactivation, they are likely to consider adjusting their behavior.  As can be seen in the graph and table, the variables that are part of the post-experimental use index had a significant and relatively large effect.  The most pronounced effect is in *Planned post-study use change*, with a difference of 0.77 standard deviations between the treatment and control groups.  The authors also asked participants to report their use of the Facebook App in the post-endline survey.  The treatment group reported an average of 0.30 standard deviations less than the control group, which would lead to believe that the participants carried out their plan.  However, as Alcott et. al (2020) notes, if we take into account only iPhone users, this effect is not only smaller but not statistically significant.  This is important, since only iPhone users were asked to report their time spent on Facebook based on the application's usage statistics.  Users with non-iOS mobile phones reported usage based on their own estimate.  This difference may be a result of one of the limitations of this experiment that was discussed earlier in the "Identification" section of this notebook.  The contrasting outcome between iPhone users and the rest may be due to the perceived demands of the experimenter.
#
# Deactivation would also seem to make people appreciate both the positive and the harmful effects of Facebook.  Consistent with the discussion above, those in the treatment group seem to appreciate more how Facebook helps to follow the news.
#
# **Figure 7** shows the probability of being deactivated per day for both the control and the treatment groups.

# %%
figureSeven <- genFigSeven(finalData)
figureSeven
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure shows the share of the Treatment and Control groups that had their Facebook accounts deactivated, by day of the experiment, for the impact evaluation sample: participants who were willing to accept less than $\$102$ to deactivate Facebook for the four weeks after midline and were offered $p = \$102$ or $p = \$0$ to do so. The vertical gray areas reflect the $24$-hour periods after midline and endline during which both Treatment and Control were instructed to deactivate.</p>

# %% [markdown]
# As shown in the figure, both the speed of reactivation and the percentage of participants deactivated vary between the control and treatment groups.  According to the authors 9 weeks after the end of the experiment 5% of the participants who were part of the treatment group still had their Facebook account deactivated, in contrast to only 2.5% of the participants who were part of the control group.
#
# **Figure 8** shows the distribution of responses to two questions related to the *Facebook opinions index*.

# %%
figureEight <- genFigEight(finalData)
figureEight
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents the distribution of responses in Treatment and Control for two key measures of opinions
# about Facebook. See Section IC for variable definitions.</p>

# %% [markdown]
# The responses of the treatment group appear to be more dispersed and with higher densities at the extremes than those of the control group.  As stated above, here it is visually evident that the deactivation made participants appreciate more the virtues of Facebook as its limitations.

# %% [markdown]
# ### *E. Heterogeneous Treatment Effects*
#
# **Figure 9** presents separate estimates for four different moderators:
# 1. People whose baseline reported Facebook use was above versus below median (*light users* vs. *heavy users*)
# 2. People who get news from Facebook fairly often or very often versus never, hardly ever, or sometimes. (*heavy news users* vs. *light news users*)
# 3. People for whom the sum of their answers to questions relevant to how they use Facebook is higher or lower than the median. (*active users* vs. *passive users*)
#     - To give more context about this moderator I transcribe one of the questions asked in the study below:
#     > *\"what share of your time on Facebook do you spend interacting one-on-one with people you care about?\"*
# 4. Answers to questions about subjective well-being at times when the person reported using more Facebook versus other times of the day. (*Peak use times* vs. *Off-peak times*)

# %%
# Regression settings
M0 <- c("minutes_fb", 0)
M1 <- c("minutes_fb", 1)
N0 <- c("news_fb", 0)
N1 <- c("news_fb", 1)
F0 <- c("fb_active", 0)
F1 <- c("fb_active", 1)

moderators <-
    c(
        "M0",
        "M1",
        "N0",
        "N1",
        "F0",
        "F1"
    )

## Run regressions.
for (mod in moderators) {
    for (vset in vset_list[vset_list != "secondary"]) {
        yvar <- paste("index_", vset, sep = "")
        eq <- setEquation(vset, yvar)
        nam <- paste(yvar, "_", mod, "_IV", sep = "")
        assign(nam, ivreg(eq,
                          data = df[df[eval(parse(text = mod))[1]] == eval(parse(text = mod))[2], ],
                          weights = weight_main))
        assign(paste(nam, "_coeftest", sep = ""),
               coeftest(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
        assign(paste(nam, "_coefci", sep = ""),
               coefci(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
    }
}

## SMS Analysis
## Run regressions.
for(var in c("happy_sms", "pos_emotion_sms", "lonely_sms")) {
    for(ptime in c("peak", "offpeak")){
        names(df)[names(df) == paste(var, "_", ptime, sep = "")] <-
            paste(var, "_temp", sep = "")
        names(df)[names(df) == paste(var, "_", ptime, "_b", sep = "")] <-
            paste(var, "_temp_b", sep = "")
        
        yvar <- paste(var, "_temp", sep = "")
        
        eq <-
            paste(
                yvar,
                "~",
                paste(yvar, "_b", sep = ""),
                "+",
                "index_swb_b",
                "+ D",
                "|",
                paste(yvar, "_b", sep = ""),
                "+",
                "index_swb_b",
                "+ T",
                sep = " "
            )
        
        nam <- paste(var, "_", ptime, "_IV", sep = "")
        
        assign(nam, ivreg(eq, data = df, weights = weight_main))
        assign(paste(nam, "_coeftest", sep = ""),
               coeftest(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
        assign(paste(nam, "_coefci", sep = ""),
               coefci(eval(parse(text = nam)), vcov = vcovHC(eval(
                   parse(text = nam)
               ), "HC3")))
        
        names(df)[names(df) == paste(var, "_temp", sep = "")] <-
            paste(var, "_", ptime, sep = "")
        names(df)[names(df) == paste(var, "_temp_b", sep = "")] <-
            paste(var, "_", ptime, "_b", sep = "")
        
    }
}

# %%
## Sub-figures

figNineAADf <-
    genFigModDf(
        yvars = c(
            "index_sub_time",
            "index_social",
            "index_sub_news",
            "index_news",
            "index_voting",
            "index_polarize",
            "index_swb",
            "index_postexp",
            "index_fbopinions"
        ), mods = c("M0", "M1")
    )

figNineABDf <-
    genFigModDf(
        yvars = c(
            "index_news",
            "index_voting",
            "index_polarize"
        ), mods = c("N0", "N1")
    )

figNineBADf <-
    genFigModDf(
        yvars = c(
            "index_social",
            "index_swb",
            "index_postexp",
            "index_fbopinions"
        ), mods = c("F0", "F1")
    )
figNineBBDf <- 
    genFigModDf(
        yvars = c("happy_sms", "pos_emotion_sms", "lonely_sms"),
        mods = c("offpeak", "peak")
    )

options(repr.plot.width=7, repr.plot.height=28, repr.plot.res=200, warn=-1)

## Generate the title.
title <- ggdraw() + 
    draw_label(
        "Figure 9. Heterogeneous Treatment Effects",
        fontface = "bold",
        x = 0,
        hjust = 0,
    ) + 
    theme(
        plot.margin = margin(0, 0, 0, 7)
    )

## Generate Figure 9.
figNine <-
    plot_grid(
        title,
        genMainModFigure(figDf = figNineAADf),
        genMainModFigure(figDf = figNineABDf),
        genMainModFigure(figDf = figNineBADf),
        genMainModFigure(figDf = figNineBBDf),
        ncol = 1,
        nrow = 5,
        rel_heights = c(0.1, 1, 1, 1, 1)
    )
figNine
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents local average treatment effects of Facebook deactivation estimated using equation (1), for subgroups defined by the primary moderators in our pre-analysis plan. All variables are normalized so that the Control group endline distribution has a standard deviation of 1. Error bars reflect 95 percent confidence intervals. See Section IC for variable definitions.</p>

# %% [markdown]
# As can be seen, there seems to be no significant difference in the effects between any the components of the 4 moderators named above.
#
# The authors argue that there may be many other factors that moderate the treatment effect.To find this effect they consider 13 other moderators:
# - 6 demographic variables: income, years of education, gender, race, age, and political party affiliation.
# - The baseline values of the 7 relevant indices.
#
# In six outcomes:
# - 5 indexes: news knowledge, political polarization, subjective well-being, post-experiment use, and Facebook opinions.
# - The variable Deactivation bad.
#
# Using the following equation:
#
# $$Y_{i} = \tau D_{i} + \alpha^{k} D_{i} X^{k}_{i} + \zeta X^{k}_{i} + \rho \mathbf{Y}_{i}^{b} + v_{s} + \varepsilon_{i}$$
#
# Instrumenting $D_{i}$ and $D_{i} X^{k}_{i}$ with $T_{i}$ and $T_{i} X^{k}_{i}$. And with $X^{k}_{i}$ being the moderator $k$ normalized to have a standard deviation of 1.
#
# The authors summarize their findings as follows:
#
# > *We highlight three key results. First, deactivation may reduce polarization more (i.e., Facebook use may increase polarization more) for older people, white people, and men. Second, Facebook deactivation has less positive effect on subjective well-being for people who have more offline social interactions and are already more happy at baseline. This suggests that Facebook use may have the unfortunate effect of reducing SWB more for people with greater social and psychological need.  In our sample, these "higher-need" people also use Facebook more heavily. Third, people may have some intuition about whether they will like deactivation: people with more positive baseline opinions about Facebook are less likely to decrease their post-experiment use and less likely to think that deactivation was good for them.* (Alcott et. al, 2020)
#
# As my own contribution I will use causal forests to determine these effects.  This is one of the alternatives that the authors describe in the original article to estimate heterogeneous treatment effects.

# %% [markdown]
# ## Causal Forests to Estimate Heterogeneous Treatment Effects
# #### *(Not in the original paper)*

# %%
## Specify analytic sample
sample <- "main"
weights <- "unweighted"

## Import data
df <- importData(finalData, sample, weights)

## Set options.
sampleFraction <- 0.2
B <- 50000

## Build the covariates matrix.
X <- df %>%
    select(
        educyears,
        male,
        white,
        age,
        repdem,
    )

# %% [markdown]
# To estimate heterogeneous treatment effects I will use generalized random forests.  A method proposed by Athey, Tibshirani, & Wager (2019) based on random forests.  Although the results may be more difficult to interpret than those in the authors' specification, this method is useful for visualizing the effects.
#
# In this section I will focus mostly in the key results described by the authors.
#
#
# All forests were grown with a subsample fraction of 0.2 and consist of 50,000 trees.  The 6 demographic moderators and the index at baseline were included. Except for the moderator which varies, the rest were set to their mean value.

# %% [markdown]
# ### *Political polarization*

# %% [markdown]
# The authors found that the deactivation of Facebook may have a more pronounced effect on reducing political polarization for older people. Using generalized random forests, we can calculate conditional local average treatment effects (CLATE) by age.  The following figure shows the CLATE by age at the top and the age density at the bottom.

# %%
# Set options
outcome <- "polarize"
varAcross <- "age"

fullMatrix <- genFullMatrix(df, X, outcome, varAcross)

## Run for(r)est run!
ivForest <- instrumental_forest(
    X = fullMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
    Y = fullMatrix[, paste0("index_", outcome)],
    W = fullMatrix[, "D"],
    Z = fullMatrix[, "T"],
    num.trees = B,
    sample.fraction = sampleFraction,
    seed = 202007
)

tau.hat <- predict(
    ivForest, 
    fullMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
    estimate.variance = TRUE)

avg.late <- average_late(ivForest)[1]

# %%
options(repr.plot.width=7, repr.plot.height=7, repr.plot.res=200, warn=-1)

## Generate density plot.
densityAge <-
    ggplot(data = data.frame(fullMatrix), aes(x = age)) + 
    geom_density(color = "#238b45", fill = "#b2e2e2", alpha = 0.4) + 
    labs(
        x = "Age",
        y = "Density"
    )

# Full 
plot_grid(
    genFigForest(X = fullMatrix, varAcross, ivForest, tau.hat, x.label = "Age"), 
    densityAge, 
    nrow = 2
)
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents: on the top, the causal effect of deactivating Facebook for four weeks on the political polarization index at different ages; and on the bottom, a density plot of the ages in the impact evaluation sample.  The dashed line represents the average LATE in the impact evaluation sample</p>

# %% [markdown]
# As can be seen in the figure, there seems to be a greater effect of political polarization reduction after deactivating as age increases. Surprisingly, after a certain age (approximately 40 years) this trend seems to turn around.  Although, as can be seen in the lower part of the figure, since there are not a large number of observations available after this age it is difficult to draw conclusions. This change in trend however, would mean that the deactivation of Facebook helps to reduce more the index of political polarization among those with an age close to 40 years in comparison with the rest.
#
# Another of the moderators that the authors claim may have a heterogeneous treatment effect on political polarization is sex.  By dividing the sample between men and women, we can gain a better understanding of the effect of deactivation on political polarization.  The following graph shows the CLATE by age for both women and men.

# %%
## Age against other variables
for(mod in c("male", "white")){
    for(i in 0:1){
        if(mod == "male"){
            scaleLimit <- c(-0.75, 0.2)
            if(i == 0){
                title = "Female"
            } else {
                title = "Male"
            }
        } else {
            scaleLimit <- c(-0.6, 0.3)
            if(i == 0){
                title = "Non-White"
            } else {
                title = "White"
            }
        }
        
        modMatrix <- genFullMatrix(
            df[df[, mod] == i, ], 
            X[X[, mod] == i, ], 
            outcome, 
            varAcross
        )
        
        ## Run fo(r)est (run)!
        ivForest <- instrumental_forest(
            X = modMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
            Y = modMatrix[, paste0("index_", outcome)],
            W = modMatrix[, "D"],
            Z = modMatrix[, "T"],
            num.trees = B,
            sample.fraction = sampleFraction,
            seed = 202007
        )
        
        tau.hat <- predict(
            ivForest, 
            modMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
            estimate.variance = TRUE)
        
        ## Plots
        assign(
            paste0("figForest", toString(i)), 
            genFigForest(
                X = modMatrix,
                varAcross,
                ivForest,
                tau.hat,
                x.label = "Age",
                y.scale = scaleLimit,
                title = title,
                hide.x.axis = FALSE,
                avg.late = avg.late
            )                
        )
        eval(parse(text = paste0("figForest", toString(i))))
    }
    assign(
        paste0("figForest", mod),
        plot_grid(figForest0, figForest1, labels = "AUTO")
    )
}

# %%
options(repr.plot.width=14, repr.plot.height=7, repr.plot.res=200, warn=-1)
figForestmale
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents the causal effect of deactivating Facebook for four weeks on the political polarization index at different ages, dividing the sample between women (A) and men (B).  The dashed line represents the average LATE and the dotted line the average LATE in the impact evaluation sample</p>

# %% [markdown]
# As can be seen, deactivation helped to reduce the index of political polarization in men more than in women.  In addition, it seems that the effect of the treatment in decreasing political polarization as age increases, is more pronounced in men, and the trend does not turn around. This could indicate that the reduction of the political polarization index as an effect of deactivation is greater for older men.
#
# Other moderator the authors cite as causing a different treatment effect in political polarization is race.  In the following figure, in the style of the previous one, the different CLATE in relation to age can be observed for those who reported their race as white as for those who reported being non-white.

# %%
figForestwhite
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents the causal effect of deactivating Facebook for four weeks on the political polarization index at different ages, dividing the sample between non-white (A) and white (B). The dashed line represents the average LATE and the dotted line the average LATE in the impact evaluation sample</p>

# %% [markdown]
# As can be seen, deactivation seems to have a slight but greater effect on political polarization reduction among those who reported their race as white as compared to the others.  There does not appear to be evidence that the effect of deactivation in reducing political polarization through ages has a different trend for those who reported their race as white.  However, for those who reported their race as non-white, the switch in trend does not appear to happen, and the treatment effect on the index of political polarization appears to be more constant across all ages.
#
# ### *Subjective well-being*
#
# Another of the authors' findings is that deactivation has a smaller effect on subjective well-being in those who initially had better subjective well-being.  The following figure shows the different CLATES of deactivation in the subjective well-being index at endline in relation to the subjective well-being index reported in the baseline survey.

# %%
# Set options
outcome <- "swb"
varAcross <- "index_swb_b"

fullMatrix <- genFullMatrix(df, X, outcome, varAcross)

## Run for(r)est run!
ivForest <- instrumental_forest(
    X = fullMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
    Y = fullMatrix[, paste0("index_", outcome)],
    W = fullMatrix[, "D"],
    Z = fullMatrix[, "T"],
    num.trees = B,
    sample.fraction = sampleFraction,
    seed = 202007
)

tau.hat <- predict(
    ivForest, 
    fullMatrix[, c(colnames(X), paste0("index_", outcome, "_b"))],
    estimate.variance = TRUE)

# %%
options(repr.plot.width=7, repr.plot.height=7, repr.plot.res=200, warn=-1)

## Generate density plot.
densitySwbB <-
    ggplot(data = data.frame(fullMatrix), aes(x = index_swb_b)) + 
    geom_density(color = "#238b45", fill = "#b2e2e2", alpha = 0.4) + 
    labs(
        x = "Subjective well-being index (baseline)",
        y = "Density"
    )

# Full figure
plot_grid(
    genFigForest(X = fullMatrix, varAcross, ivForest, tau.hat, x.label = "Subjective well-being index (baseline)"), 
    densitySwbB, 
    nrow = 2
)
# Out:
# plot without title

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents: on the top, the causal effect of deactivating Facebook for four weeks on the subjective well-being index at different points of the estimated subjective well-being index at baseline; and on the bottom, a density plot of the estimated subjective well-being index at baseline. The dashed line represents the average LATE in the impact evaluation sample</p>

# %% [markdown]
# In the figure above it can be seen that deactivation had a greater positive effect on the subjective well-being for those who reported having lower subjective well-being at baseline. This contradicts the findings reported by the authors.  We can see that the mostly downward trend is interrupted, and inverted, when the subjective well-being in the baseline takes the value of 0, and then inverted again when the baseline index takes the value of roughly 0.5.  The great density of observations between these two values could explain the discrepancy between what the authors found and what can be observed in the figure.
#
# Nevertheless, using general random forests to determine the effects of deactivation on subjective well-being, we can conclude that the positive effect of deactivation is greater on those who had a lower score in the subjective well-being index at baseline. Especially for those with a score close to -1 at baseline. Only among those with a calculated score between -0.5 and -1, and between 0 and 0.5 does the opposite appear to be true. We can also note that for those with a score greater than 1 on the subjective well-being index, the deactivation effect seems to change symbols. That is, deactivating Facebook for these users could lead to a reduction in subjective well-being.
#
# Using generalized random forests for a instrumental variables regression to estimate heterogeneous treatment effects through CLATE estimation is an innovative method that can help to further visualize in detail the scope of these effects.  However, it has several limitations compared to traditional methods.  As Athey et al. (2019) state, the confidence intervals are quite wide, this is an obstacle in determining the significance of the results.  Similarly, the estimates obtained can be very sensitive to different tuning parameters, or even to chance.

# %% [markdown]
# ## Measuring the Consumer Surplus from Facebook
# #### *(Section V in the original paper)*
#
# ### *A. Standard Consumer Surplus Estimate*
#
# Measuring the consumer's surplus of services that have no apparent price for their use, like Facebook, is a difficult endeavour. Alcott et al. (2020) first calculate the consumer surplus using the standard model, where it is assumed that the surplus can be identified with the WTA.  **Figure 11** shows the distribution of participants' willingness to accept for deactivating Facebook for 4 weeks instead of 24 hours after the midline.

# %%
options(repr.plot.width=7, repr.plot.height=7, repr.plot.res=200, warn=-1)
figEleven <- genFigEleven(finalData)
figEleven

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents the distribution of willingness-to-accept to deactivate Facebook between midline and endline. All responses above \$525 are plotted at \$525.</p>

# %% [markdown]
#  After weighting for the demographic characteristics of the Facebook user population in the United States as shown in **Table 2**, the authors estimate that the average WTA is $180. If we multiply this value by the number of the estimated active users in the United States, it would imply that the consumer surplus from Facebook would be of approximately 3.87 billion dollars per day in the US alone.

# %% [markdown]
# ### *B. How Deactivation Affects Valuations*
#
# It may be the case that people do not adequately calculate the true value of Facebook. Deactivation for four weeks might help people evaluate Facebook better.  The authors elucidated the participants' WTA to deactivate Facebook for 4 weeks instead of 24 hours at three points:
#
# - At the midline survey they asked:
#     - $w_{1}$:= WTA to deactivate Facebook the 4 weeks after the midline (weeks 1-4) before telling them the BDM offered price.
#     - $w_{2,1}$:= WTA to deactivate Facebook the 4 weeks after the endline (weeks 5-8) after telling them the BDM offered price.
# - At the endline survey they asked:
#     - $w_{2,2}$:= WTA to deactivate Facebook the 4 weeks after the endline (weeks 5-8).
#
# **Figure 12** shows the mean of these responses divided between control and treatment groups winsorized at $\$170$.

# %%
figTwelve <- genFigTwelve(finalData)
figTwelve

# %% [markdown]
# <p style="font-size:12px"><i>Notes</i>: This figure presents the mean willingness-to-accept (WTA) to deactivate Facebook in Treatment and Control, for the impact evaluation sample: participants who were willing to accept less than \$102 to deactivate Facebook for the four weeks after midline and were offered $p= \$102$ or $p = \$0$ to do so. The first pair of bars is the mean WTA for deactivation in weeks 1-4, the four weeks after the midline survey. The second pair of bars is mean WTA for deactivation in weeks 5-8, the four weeks after the endline survey, as elicited in the midline survey. The third pair of bars is mean WTA for deactivation in weeks 5-8, as elicited in the endline survey.</p>

# %% [markdown]
# As can be seen, the average willingness-to-accept between questions asked in the midline survey increases sharply for the treatment group, while this difference can not be appreciated in the control group.  The authors argue that this may be because the costs of deactivation are convex in the duration of the deactivation, or because of the anchorage in the \$102 BDM offer that was revealed after elucidating the WTA.
#
# Another interesting finding that can be seen in the graph, is that the willingness to deactivate Facebook for 4 weeks instead of 24 hours in weeks 5 - 8 by the participants in the control group increased over time (between the midline and the end line).  This change may be due to the fact that at the time the deactivation was intended to take place, holidays such as Thanksgiving were celebrated and participants did not take this into account when making their assessment in the first survey. Alcott et. al (2020) argue that evidence of this can be found in the open questions of the survey.
#
#
# Nevertheless, defining $\Delta w_{2} := w_{2,2} - w_{2,1}$.  We can capture any time effect plus any other effect that causes change in valuation.  If we consider that the time effect is the same for both groups.  We can estimate the effect of the deactivation on the change of valuation using the following regression:
# $$\Delta w_{2,i} = \gamma D_{i} + \rho w_{1,i} + v_{s} + \varepsilon_{i}$$
# Instrumenting $D_{i}$ with  $T_{i}$.
#
# The authors present the results of this estimate in **Table 6** of the article, which I reproduce below.

# %%
suppressWarnings(tableSix <- genTableSix(finalData))
display_html(tableSix)

# %% [markdown]
# The treatment group reduced its valuation by $\$14$ to $\$19$ compared to the control group.  This may be evidence that a "digital detox" can make people evaluate better the benefits they get from using plataforms like Facebook

# %% [markdown]
# ## Conclusions
#
# Alcott et. al (2020) present probably one of the largest experimental studies ever conducted regarding the welfare effects of social media, by number of participants, and by the amount of effects that were evaluated.  The authors also submitted a pre-analysis plan, which helps dispel doubts about data-mining. However, because of the type of study, special care must be taken in interpreting the results. Not only because of the limitations discussed above, but also because of the difficulties of generalizing the findings.  Nevertheless, the authors note these problems and elaborate on ways to address them.
#
# With the replication file provided by the authors it is possible to reproduce the original article with a few simple commands.  It also has detailed instructions on how to carry out the process, as well as explanations on each step of the operation.  This judicious approach by the authors gives transparency to the research carried out and is evidence of good practices.  Using a different software than the one used by the authors I was able to reproduce most of the tables and figures present in the original article with very similar results. Using randomized forests I was able to estimate conditional local average treatment effects to use in the analysis of heterogeneity of treatment effects.  This approach has both advantages and limitations.
#
# The effect, both positive and negative, that social networks have had on our lives is undeniable.  The authors found that deactivating Facebook for 4 weeks can have an effect on various aspects of well-being, as well as on the valuation of the social network.

# %% [markdown]
# ## References

# %% [markdown]
# - Allcott, H., Braghieri, L., Eichmeyer, S., & Gentzkow, M. (2020). The welfare effects of social media. *American Economic Review, 110*(3), 629-76. [doi:10.1214/18-AOS1709](https://doi.org/10.1214%2F18-AOS1709).
# - Athey, S., Tibshirani, J., & Wager, S. (2019). Generalized random forests. *The Annals of Statistics, 47*(2), 1148-1178.  [arXiv:1610.01271 \[**stat.ME**\]](https://arxiv.org/abs/1610.01271).
# - Boxell, L. (2020). Demographic change and political polarization in the United States. *Economics Letters*, 109187. [doi:10.2139/ssrn.3148805](https://doi.org/10.2139/ssrn.3148805)
# - Facebook (2016). Facebook (FB) Mark Elliot Zuckerberg on Q1 2016 Results - Earnings Call Transcript. *Seeking Alpha*. Retrieved from: https://seekingalpha.com/article/3968783-facebook-fb-mark-elliot-zuckerberg-on-q1-2016-results-earnings-call-transcript
# - Facebook (2020). *Facebook Reports First Quarter 2020 Results*.  \[Press release\]. Retrieved from: https://investor.fb.com/investor-news/press-release-details/2020/Facebook-Reports-First-Quarter-2020-Results/default.aspx
# - GlobalWebIndex. (2020a). *GlobalWebIndex’s flagship report on the latest trends in social media*.
# - GlobalWebIndex. (2020b). *GWI Coronavirus Research | July 2020 Multi-market research wave 5*. Retrieved from: https://www.globalwebindex.com/hubfs/1.%20Coronavirus%20Research%20PDFs/GWI%20coronavirus%20findings%20July%202020%20-%20Multi-Market%20Research%20(Release%2011).pdf
# - Lee, D. S. (2009). Training, wages, and sample selection: Estimating sharp bounds on treatment effects. *The Review of Economic Studies, 76*(3), 1071-1102.[doi:0.1111/j.1467-937X.2009.00536.x](https://doi.org/10.1111/j.1467-937X.2009.00536.x)
